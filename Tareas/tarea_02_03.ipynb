# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinSantaGitHub/curso-estadistica-multivariante/blob/master/Tareas/tarea_02_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MartinSantaGitHub/curso-estadistica-multivariante/master/Datos/companies79.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                            V1     V2  ...      V6    V7             V8
# 0           1                  BellAtlantic  19788  ...  2576.8  79.4  Communication
# 1           2            ContinentalTelecom   5074  ...   578.3  21.9  Communication
# 2           3         AmericanElectricPower  13621  ...   898.9  23.4         Energy
# 3           4              BrooklynUnionGas   1117  ...    91.7   3.8         Energy
# 4           5  CentralIllinoisPublicService   1633  ...   135.9   2.8         Energy
#
# [5 rows x 9 columns]

# %%
df.shape
# Out:
# (79, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  79 non-null     int64
#  1   V1          79 non-null     object
#  2   V2          79 non-null     int64
#  3   V3          79 non-null     int64
#  4   V4          79 non-null     int64
#  5   V5          79 non-null     float64
#  6   V6          79 non-null     float64
#  7   V7          79 non-null     float64
#  8   V8          79 non-null     object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 5.7+ KB

# %%
df.rename(columns = {'V1' : 'Name', 
                     'V2' : 'Goods',
                     'V3': 'Sells',
                     'V4': 'MarketValue',
                     'V5' : 'Profits',
                     'V6' : 'CashFlow',
                     'V7' : 'Employees',
                     'V8' : 'Department'}, inplace = True)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df['Department'] = df['Department'].astype('category')
df['Name'] = df['Name'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         79 non-null     string
#  1   Goods        79 non-null     int64
#  2   Sells        79 non-null     int64
#  3   MarketValue  79 non-null     int64
#  4   Profits      79 non-null     float64
#  5   CashFlow     79 non-null     float64
#  6   Employees    79 non-null     float64
#  7   Department   79 non-null     category
# dtypes: category(1), float64(3), int64(3), string(1)
# memory usage: 4.9 KB

# %%
Xf = df.iloc[:,1:7]
Xf.head()
# Out:
#    Goods  Sells  MarketValue  Profits  CashFlow  Employees
# 0  19788   9084        10636   1092.9    2576.8       79.4
# 1   5074   2557         1892    239.9     578.3       21.9
# 2  13621   4848         4572    485.0     898.9       23.4
# 3   1117   1038          478     59.7      91.7        3.8
# 4   1633    701          679     74.3     135.9        2.8

# %%
scaler = StandardScaler()
scaled_features =scaler.fit_transform(Xf.values)
df_features_scaled = pd.DataFrame(scaled_features, index=Xf.index, columns=Xf.columns)

plt.figure(figsize = (14,8))
sns.boxplot(data = df_features_scaled)
plt.xticks(rotation = 90)
plt.tight_layout()

# %%
df_features_scaled_y = pd.concat([df_features_scaled, df.iloc[:,7]], axis=1).reindex(df_features_scaled.index)
df_features_scaled_y.boxplot(by="Department", figsize=(24, 12))
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5f073c1150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5f073737d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5f073b8e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5f072e6990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5f0729fa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5f07257b90>]],
#       dtype=object)

# %%
plt.figure(figsize = (14,8))
lc = len(df.columns)

for i in range(1,lc):
  sns.displot(df.iloc[:,i],bins=10,kde=True)
  if (i == lc - 1):
    plt.xticks(rotation = 90)

# %%
sns.pairplot(df_features_scaled_y, diag_kind="kde", height=1.5)

# %%
def print_scatter_matrix(df,target,color_dict):
  colors = df[target].map(lambda x: color_dict.get(x))
  scatter_matrix(df, c = colors, alpha = 0.5, figsize = (15, 15))
  plt.show()

# %%
df_features_scaled_y.iloc[:,6].cat.categories

color_dict = {'Communication': "blue", 'Energy': "red", 'Finance' : 'pink', 'HiTech': 'yellow',
                  'Manufacturing' : 'black', 'Medical' : 'green', 'Other' : 'brown', 'Retail' : 'cyan', 'Transportation' : 'purple'}

print_scatter_matrix(df_features_scaled_y,"Department",color_dict)

# %%
df_features_y = pd.concat([Xf, df.iloc[:,7]], axis=1).reindex(Xf.index)
num_col_names = df_features_y.columns.tolist()
num_col_names.pop()
df_features_y[num_col_names] = df_features_y[num_col_names].apply(np.log10, axis = 1)

color_dict = {'Communication': "blue", 'Energy': "red", 'Finance' : 'pink', 'HiTech': 'yellow',
                  'Manufacturing' : 'black', 'Medical' : 'green', 'Other' : 'brown', 'Retail' : 'cyan', 'Transportation' : 'purple'}

print_scatter_matrix(df_features_y,"Department",color_dict)

# %%
np.mean(Xf)
# Out:
# Goods          5940.531646
# Sells          4178.291139
# MarketValue    3269.746835
# Profits         268.289873
# CashFlow        433.455696
# Employees        37.597468
# dtype: float64

# %%
cov_matrix = pd.DataFrame(np.cov(Xf, rowvar = False))
cov_matrix.columns = num_col_names
cov_matrix.index = num_col_names
cov_matrix

# También se puede utilizar
Xf.cov()
# Out:
#                 Goods     Sells  MarketValue   Profits  CashFlow  Employees
# Goods        1.000000  0.746465     0.682212  0.719771  0.705556   0.594358
# Sells        0.746465  1.000000     0.878892  0.891879  0.892804   0.924043
# MarketValue  0.682212  0.878892     1.000000  0.987557  0.978051   0.818216
# Profits      0.719771  0.891879     0.987557  1.000000  0.987456   0.802611
# CashFlow     0.705556  0.892804     0.978051  0.987456  1.000000   0.799481
# Employees    0.594358  0.924043     0.818216  0.802611  0.799481   1.000000

# %%
sns.heatmap(Xf.corr(), vmax=1, vmin=-1, cmap ='GnBu', annot=True, fmt='.2f', center = 0)
